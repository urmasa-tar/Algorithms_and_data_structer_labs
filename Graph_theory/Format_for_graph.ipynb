# %%
import numpy as np
import pandas as pd

# %%
grap_part = pd.read_excel('points_of_map.xlsx')

grap_part
# Out:
#     img - 200%      1     2      3      4     5     6     7     8     9  ...  \
# 0            1    0.0  60.0    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1            2   60.0   0.0   14.0    NaN   NaN   NaN  52.0   NaN   NaN  ...
# 2            3    NaN  14.0    0.0  130.0   NaN   NaN   NaN  50.0   NaN  ...
# 3            4    NaN   NaN  130.0    0.0  54.0   NaN   NaN   NaN   NaN  ...
# 4            5    NaN   NaN    NaN   54.0   0.0  22.0   NaN   NaN   NaN  ...
# 5            6    NaN   NaN    NaN    NaN  22.0   0.0   NaN   NaN   NaN  ...
# 6            7    NaN  52.0    NaN    NaN   NaN   NaN   0.0  15.0   NaN  ...
# 7            8    NaN   NaN   50.0    NaN   NaN   NaN  15.0   0.0  26.0  ...
# 8            9    NaN   NaN    NaN    NaN   NaN   NaN   NaN  26.0   0.0  ...
# 9           10    NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN  94.0  ...
# 10          11    NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
type(grap_part)
# Out:
# pandas.core.frame.DataFrame
